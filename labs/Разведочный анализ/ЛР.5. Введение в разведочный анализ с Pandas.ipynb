# %% [markdown]
# # Лабораторная работа №5. Введение в разведочный анализ с Pandas

# %% [markdown]
# В этом задании вы сможете попрактиковаться в некоторых концепциях и навыках по обработке данных с помощью библиотеки Pandas.
#
# Просматривая этот блокнот, вы найдете **???** в определенных местах. Для выполнения этого задания необходимо заменить все **???** с соответствующими значениями, выражениями или операторами, чтобы обеспечить правильную сквозное выполнение блокнота.
#
# Некоторые вещи, которые следует иметь в виду:
# - Обязательно запустите все ячейки кода, иначе вы можете получить ошибки, например, NameError для неопределенных переменных.
# - Не изменяйте имена переменных, не удаляйте ячейки и не нарушайте другой существующий код. Это может вызвать проблемы во время оценки.
# - В некоторых случаях вам может понадобиться добавить некоторые ячейки кода или новые операторы до или после строки кода, содержащей ???.
# - Вопросы, отмеченные (необязательно), не будут рассматриваться для оценки и могут быть пропущены. Они для вашего обучения.

# %% [markdown]
# ## Как запустить код и сохранить свою работу

# %% [markdown]
# Рекомендуемый способ запуска этой записной книжки — выбрать пункт меню «Среда выполнения» (если вы работаете в Google Colab) и нажать "Выполнить все".

# %%
# Run the next line to install Pandas
# !pip install pandas --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %% [markdown]
# В этом задании мы собираемся проанализировать работу с данными из файла CSV. Начнем с загрузки CSV-файла. Файл размещен в репозитории https://github.com/SerjiEvg/data-analysis/raw/main/data/grades.csv.

# %%
df = ???

df

# %% [markdown]
# ### **Задание 1. Изучение набора данных?**
#
# Чтобы понять набор данных, введите с помощью команд Pandas: a) head, б) tail, c) dtypes, д) info, е) describe

# %%
#a) (1)

# %%
#б) (1)

# %%
#c) (1)

# %%
#д) (1)

# %%
#e) (1)

# %% [markdown]
# ### **Задание 2. Очистка набора данных**

# %% [markdown]
# a) Используйте приведенный ниже метод clean_currency, чтобы удалить запятые и знаки денежной единицы из столбца «Сбережения» (Руб.) и поместить их в новый столбец под названием «Сбережения».

# %%
def clean_currency(curr):
    return float(curr.replace(",", "").replace("руб.", ""))

clean_currency("66,000 руб.")
# Out:
# 66000.0

# %%
# Избавьтесь от руб. и , в столбце Сбережения, чтобы конвертировать в формат float

# %% [markdown]
# б) Выведите grades.dtypes.Сбережения, чтобы проверить, произошло ли изменение типа.

# %%
#б)

# %% [markdown]
# с) Запустите 'grades["Пол"].value_counts()', чтобы увидеть неправильные поля «М», которые необходимо преобразовать в «Муж.».

# %%
# с)

# %% [markdown]
# д) Теперь используйте «.str.replace» в столбце «Пол», чтобы скрыть неправильные поля «M». Подсказка: мы должны использовать ^...$, чтобы ограничить шаблон соответствием всей строке.

# %%
# д)


df["Пол"].value_counts()

# %%
df

# %% [markdown]
# е) Однако это не относится к установленному столбцу выпускников ["Пол"]. Вам нужно будет обновить столбец при использовании команды замены 'alumni["Gender"]= ', покажите, как это делается ниже

# %%
# е) (1)

# %% [markdown]
# ж) Вы можете установить его напрямую с помощью команды df.loc, покажите, как это можно сделать с помощью команды «df.loc[row_indexer,col_indexer] = value» для преобразования «M» в «Мужской».

# %%
# ж) (1)

# %% [markdown]
# з) Теперь снова запустите «value_counts» для пола, чтобы увидеть правильные столбцы — «Мужской» и «Женский».

# %%
# з) (1)

# %% [markdown]
# ### **Задание 3. Анализ данных**

# %% [markdown]
# a) получить медиану, б) вычислить среднее c) выяислить стандартное отклонение для столбца 'Зарплата'

# %%
# a)(1)

# %%
# b)(1)

# %%
# c)(1)

# %% [markdown]
# д) определить, какие выпускники заплатили более 15000 руб., используя столбец «Платеж».

# %%
# д) (1)

# %% [markdown]
# ### **Задание 4. Визуализация данных**

# %% [markdown]
# a) Используя столбец «Тип диплома», постройте столбчатую диаграмму и покажите количество ее значений.

# %%
#a) (1)

# %% [markdown]
# б) Создайте прямоугольную диаграмму для сравнения столбцов "Зарплата" и "Сбережения"

# %%
#b) (1)

# %% [markdown]
# c) Создайте гистограмму со столбцом «Зарплата», используя 12 интервалов.

# %%
#c) (1)

# %% [markdown]
# д) Создайте точечный график, сравнивая столбцы «Зарплата» и «Сбережения».

# %%
#d) (1)

# %% [markdown]
# ## **Сохранение и отправка**

# %% [markdown]
# Если вы работаете с сервисом Google Colab, то в меню "Файл" выберите пункт "Скачать" в формате .IPYNB. Это ваша версия блокнота. Загрузите блокнот как ответ на задание.
