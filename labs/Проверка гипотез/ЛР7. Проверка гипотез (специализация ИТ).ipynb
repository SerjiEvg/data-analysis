# %% [markdown]
# # Лабораторная работа №7 Проверка гипотез (специализация ИТ)

# %% [markdown]
# `Гипотезы` — это утверждения, и мы можем использовать статистику, чтобы подтвердить или опровергнуть их. На этом этапе проверка гипотез структурирует проблемы таким образом, чтобы мы могли использовать статистические данные для проверки этих утверждений. Таким образом, мы можем проверить, является ли утверждение действительным.

# %% [markdown]
# ### Цель лабораторной работы:

# %% [markdown]
# В этой лаборторной работе нужно познакомится с алгоритмом проверки статистических гипотез.
#
# Изучаются следующие вопросы:
#
# *   Правильное формулирование статитистических гипотез
# *   Проверка предположений - независимости и нормальности данных
# *   Выбор соответствующего статистического теста
# *   Интерпретация результатов
#
# Лабораторная работа предоставляется на проверку в виде блокнота Jupyter Notebook с сформированными ответами в кодовых ячейках и вычисленным результатом. Ячейки с заданиями удалять не нужно.

# %% [markdown]
# ## 1. Основные шаги проверки гипотез

# %% [markdown]
# ### 1.1. Определение гипотез

# %% [markdown]
# Прежде всего, мы должны понять, на какой научный вопрос мы ищем ответ, и он должен быть сформулирован в виде `Нулевой гипотезы` (H₀) и `Альтернативной гипотезы` (H₁ или Hₐ). Помните, что H₀ и H₁ должны быть взаимоисключающими, а H₁ не должно содержать равенства:

# %% [markdown]
# - H₀: μ=x, H₁: μ≠x
#
# - H₀: μ≤x, H₁: μ>x
#
# - H₀: μ≥x, H₁: μ<x

# %% [markdown]
# ### 1.2. Проверка предположений

# %% [markdown]
# Чтобы решить, использовать ли параметрическую или непараметрическую версию теста, мы должны проверить конкретные требования, перечисленные ниже:
#
# - Наблюдения в каждой выборке независимы и одинаково распределены (IID).
#
# - Наблюдения в каждой выборке распределены нормально.
#
# - Наблюдения в каждой выборке имеют одинаковую дисперсию.

# %% [markdown]
# ### 1.3. Выбор правильного теста

# %% [markdown]
# Затем мы выбираем соответствующий тест для использования. При выборе правильного теста важно проанализировать, сколько групп сравнивается и являются ли данные парными или нет. Чтобы определить, совпадают ли данные, необходимо рассмотреть, были ли данные собраны от одних и тех же лиц.
#
# Соответственно, мы можем определиться с подходящим тестом, используя приведенную ниже схему.

# %% [markdown]
# <img src="https://github.com/SerjiEvg/data-analysis/raw/main/images/%D0%A1%D1%85%D0%B5%D0%BC%D0%B0%20%D0%B2%D1%8B%D0%B1%D0%BE%D1%80%D0%B0%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%B0%20%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D1%80%D0%BA%D0%B8%20%D0%B3%D0%B8%D0%BF%D0%BE%D1%82%D0%B5%D0%B7%D1%8B.png" width="1000"/>

# %% [markdown]
# ### 1.4. Решение и заключение

# %% [markdown]
# После выполнения проверки гипотезы мы получаем связанное значение p, которое показывает значимость теста.
#
# Если p-значение меньше, чем `альфа (уровень значимости)`, то имеется достаточно доказательств, чтобы доказать, что H₀ недействителен; мы можем отказаться от H₀.
#
# В противном случае мы не сможем отвергнуть H₀. Пожалуйста, помните, что отказ от H₀ подтверждает H₁. Однако отказ от отклонения H₀ не означает, что H₀ действителен, и не означает, что H₁ неверен.

# %% [markdown]
# ## 2. Задания по проверке гипотез

# %% [markdown]
# ### 2.1. "Въедливый" кадровик

# %% [markdown]
# Специалист по кадрам, работающий в железнодорожной компании, интересуется сверхурочным временем разных бригад.
#
# Чтобы выяснить, есть ли разница между сверхурочной работой бригады слесарей и бригады электромонтеров, он случайным образом выбрал 17 сотрудников в каждой из двух бригад и записал их среднее сверхурочное время за неделю в пересчете на час.
#
# Данные представлены ниже.

# %%
electrician = [6.2, 7.1, 1.5, 2,3, 2, 1.5, 6.1, 2.4, 2.3, 12.4, 1.8, 5.3, 3.1, 9.4, 2.3, 4.1]
 
locksmith = [2.3, 2.1, 1.4, 2.0, 8.7 , 2.2, 3.1, 4.2, 3.6, 2.5, 3.1, 6.2, 12.1, 3.9, 2.2, 1.2, 3.4]

# %% [markdown]
# В соответствии с этой информацией проведите проверку гипотезы, чтобы проверить, есть ли разница между переутомлением двух бригад, используя уровень значимости 0,05. Прежде чем приступать к проверке гипотез, проверьте соответствующие предположения.

# %% [markdown]
# #### 1. Определение гипотезы

# %% [markdown]
# В этой ячейке сформулируйте определения гипотез.

# %% [markdown]
# #### 2. Проверка предположений

# %%
# Разработайте программный код для проверки предположений и сделайте выводы

# %% [markdown]
# #### 3. Выбор правильного теста

# %%
# Сформируйте программный код для проверки гипотезы

# %% [markdown]
# #### 4. Решение и заключение

# %% [markdown]
# В этой ячейке сделайте выводы по сформулированной гипотезе.

# %% [markdown]
# ### 2.2. Начинающий маркетолог

# %% [markdown]
# Производственная компания регулярно размещает рекламу своей продукции на Rutube, VK и Telegram. Однако новому маркетолдогу было любопытно, есть ли разница между количеством клиентов, привлеченных этими платформами. Поэтому она начала использовать приложение, позволяющее узнать, откуда приходят пользователи.
#
# Ежедневные цифры, сообщаемые приложением для каждой платформы, приведены ниже.

# %%
Rutube = [1913, 1879, 1939, 2146, 2040, 2127, 2122, 2156, 2036, 1974, 1956, 2146, 2151, 1943, 2125]

VK = [2305., 2355., 2203., 2231., 2185., 2420., 2386., 2410., 2340., 2349., 2241., 2396., 2244., 2267., 2281.]

Telegram = [2133., 2522., 2124., 2551., 2293., 2367., 2460., 2311., 2178., 2113., 2048., 2443., 2265., 2095., 2528.]

# %% [markdown]
# В соответствии с этой информацией проведите проверку гипотез, чтобы проверить, есть ли разница между средним числом привлеченных клиентов на этих трех платформах с использованием уровня значимости 0,05.
#
# Если есть значительная разница, выполните дальнейший анализ, чтобы найти причину разницы. Прежде чем приступать к проверке гипотез, проверьте соответствующие предположения.

# %% [markdown]
# #### 1. Определение гипотезы

# %% [markdown]
# В этой ячейке сформулируйте определения гипотез.

# %% [markdown]
# #### 2. Проверка предположений

# %%
# Разработайте программный код для проверки предположений и сделайте выводы

# %% [markdown]
# #### 3. Выбор правильного теста

# %%
# Сформируйте программный код для проверки гипотезы

# %% [markdown]
# #### 4. Решение и заключение

# %% [markdown]
# В этой ячейке сделайте выводы по сформулированной гипотезе.

# %% [markdown]
# ### 2.3. Пора худеть!

# %% [markdown]
# При медицинском обследовании коллектива цеха по производству колбасной продукции, врачи диагностировали у восемнадцати работников высокий уровень холестерина. Медицинский персонал рассказал пациентам об опасности высокого уровня холестерина и прописал диету. Через шесть месяцев больные пришли на повторное обследование, и у них повторно проверили уровень холестерина.
#
# Проверьте, есть ли разница в уровнях холестерина у пациентов.

# %% [markdown]
# В соответствии с этой информацией проведите проверку гипотезы, чтобы выяснить, есть ли снижение уровня холестерина у пациентов после диеты, используя уровень значимости 0,05.
#
# Прежде чем приступать к проверке гипотез, проверьте соответствующие предположения. Данные по обследованиям приведены ниже

# %%
medical examination_before_diet = [224, 235, 223, 253, 253, 224, 244, 225, 259, 220, 242, 240, 239, 229, 276, 254, 237, 227] 

medical examination_after_diet = [198, 195, 901, 903 , 246, 206, 225, 199, 214, 210, 188, 205, 200, 220, 190, 199, 191, 218]

# %% [markdown]
# #### 1. Определение гипотезы

# %% [markdown]
# В этой ячейке сформулируйте определения гипотез.

# %% [markdown]
# #### 2. Проверка предположений

# %%
# Разработайте программный код для проверки предположений и сделайте выводы

# %% [markdown]
# #### 3. Выбор правильного теста

# %%
# Сформируйте программный код для проверки гипотезы

# %% [markdown]
# #### 4. Решение и заключение

# %% [markdown]
# В этой ячейке сделайте выводы по сформулированной гипотезе.
