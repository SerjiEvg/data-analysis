# %% [markdown]
# # Практическое задание №2 (работа с библиотекой Pandas)

# %% [markdown]
# В этом задании вы сможете попрактиковаться в некоторых концепциях и навыках по обработке данных с помощью библиотеки Pandas.
#
# Просматривая этот блокнот, вы найдете **???** в определенных местах. Для выполнения этого задания необходимо заменить все **???** с соответствующими значениями, выражениями или операторами, чтобы обеспечить правильную сквозное выполнение блокнота.
#
# Некоторые вещи, которые следует иметь в виду:
# - Обязательно запустите все ячейки кода, иначе вы можете получить ошибки, например, NameError для неопределенных переменных.
# - Не изменяйте имена переменных, не удаляйте ячейки и не нарушайте другой существующий код. Это может вызвать проблемы во время оценки.
# - В некоторых случаях вам может понадобиться добавить некоторые ячейки кода или новые операторы до или после строки кода, содержащей ???.
# - Вопросы, отмеченные (необязательно), не будут рассматриваться для оценки и могут быть пропущены. Они для вашего обучения.

# %% [markdown]
# ## Как запустить код и сохранить свою работу

# %% [markdown]
# Рекомендуемый способ запуска этой записной книжки — выбрать пункт меню «Среда выполнения» (если вы работаете в Google Colab) и нажать "Выполнить все".

# %%
# Run the next line to install Pandas
# !pip install pandas --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %% [markdown]
# В этом задании мы собираемся проанализировать работу с данными из файла CSV. Начнем с загрузки CSV-файла. Файл размещен в репозитории https://github.com/SerjiEvg/data-analysis/raw/main/data/countries.csv.

# %%
countries_df = pd.read_csv('https://github.com/SerjiEvg/data-analysis/raw/main/data/countries.csv')

countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# ### **Задание 1. Сколько стран содержит фрейм данных?**

# %% [markdown]
# *Подсказка:* используйте метод .shape.

# %%
num_countries = ???

# %%
print('There are {} countries in the dataset'.format(num_countries))

# %% [markdown]
# ### **Задание 2. Получить список континентов из фрейма данных?**

# %% [markdown]
# *Подсказка:* используйте метод ряда .unique.

# %%
continents = ???

# %%
continents

# %% [markdown]
# ### **Задание 3. Какова общая численность населения всех стран, перечисленных в этом наборе данных?**

# %%
total_population = ???

# %%
print('Численность населения равна {}.'.format(int(total_population)))

# %% [markdown]
# ##### **Вопрос. (необязательно) Какова общая продолжительность жизни в мире?**

# %% [markdown]
# *Подсказка:* вам нужно взять средневзвешенную ожидаемую продолжительность жизни, используя население в качестве весов.

# %% [markdown]
# ### **Задание 4. Создайте фрейм данных, содержащий 10 стран с наибольшим населением.**

# %% [markdown]
# *Подсказка:* свяжите методы sort_values и .head

# %%
most_populous_df = ???

# %%
most_populous_df

# %% [markdown]
# ### **Задание 5. Добавьте новый столбец countries_df для записи общего ВВП по стране (произведение населения и ВВП на душу населения).**

# %%
countries_df['gdp'] = ???

# %%
countries_df

# %% [markdown]
# ##### **Вопрос. (Необязательно) Создайте фрейм данных, содержащий 10 стран с самым низким ВВП на душу населения среди округов с населением более 100 миллионов человек.**

# %% [markdown]
# ## **Задание 6. Создать фрейм данных, содержащий количество стран на каждом континенте?**

# %% [markdown]
# **Подсказка:** используйте groupby, выберите  столбец location и агрегируйте с помощью count.

# %%
country_counts_df = ???

# %%
country_counts_df

# %% [markdown]
# ## **Задание 7. Создайте фрейм данных, показывающий общую численность населения каждого континента.**

# %% [markdown]
# *Подсказка:* используйте groupby, выберите столбец совокупности и агрегируйте, используя sum.

# %%
continent_populations_df = ???

# %%
continent_populations_df

# %% [markdown]
# Давайте загрузим еще один CSV-файл, содержащий общую статистику Covid-19 для разных стран, и прочитаем данные в другой фрейм данных Pandas.

# %%
covid_data_df = pd.read_csv('https://github.com/SerjiEvg/data-analysis/raw/main/data/covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# ### **Задание 8. Подсчитайте количество стран, по которым  отсутствуют данные total_tests.**

# %% [markdown]
# *Подсказка:* используйте метод .isna.

# %%
total_tests_missing = ???

# %%
print("Данные по общему количеству тестов отсутствуют для {} стран.".format(int(total_tests_missing)))

# %% [markdown]
# Давайте объединим два фрейма данных и вычислим еще несколько показателей.

# %% [markdown]
# ### **Задание 9. Объединить countries_df с covid_data_df в столбце location.**

# %% [markdown]
# *Подсказка:* используйте .merge метод на countries_df

# %%
combined_df = ???

# %%
combined_df

# %% [markdown]
# ### **Задание 10. Добавьте столбцы tests_per_million и cases_per_million в deaths_per_million combined_df**

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population']

# %%
combined_df['cases_per_million'] = ???

# %%
combined_df['deaths_per_million'] = ???

# %%
combined_df

# %% [markdown]
# ### **Задание 11. Создайте фреймворк данных с 10 странами с наибольшим количеством тестов на миллион человек.**

# %%
highest_tests_df = ???

# %%
highest_tests_df

# %% [markdown]
# ### **Задание 12. Создайте фрейм данных с 10 странами с наибольшим количеством положительных случаев на миллион человек.**

# %%
highest_cases_df = ???

# %%
highest_cases_df

# %% [markdown]
# ### **Задание 13. Создайте фрейм данных с 10 странами с наибольшим числом смертей на миллион человек?**

# %%
highest_deaths_df = ???

# %%
highest_deaths_df

# %% [markdown]
# ### **Задание 14. (Необязательно) Подсчитайте количество стран, которые фигурируют в обоих списках «наибольшее количество тестов на миллион» и «наибольшее количество случаев на миллион».**

# %% [markdown]
# ### **Задание 15. (Необязательно) Подсчитайте количество стран, которые входят в оба списка «20 стран с самым низким ВВП на душу населения» и «20 стран с самым низким количеством больничных коек на тысячу населения». При создании списка учитывайте только страны с населением более 10 миллионов человек.**

# %% [markdown]
# ## **Сохранение и отправка**

# %% [markdown]
# Если вы работаете с сервисом Google Colab, то в меню "Файл" выберите пункт "Скачать" в формате .IPYNB. Это ваша версия блокнота. Загрузите блокнот как ответ на задание.
