# %% [markdown]
# # Алгоритмы машинного обучения.

# %% [markdown]
# `Машинное обучение (ML)` — это использование математических моделей данных, которые помогают компьютеру обучаться без непосредственных инструкций.

# %% [markdown]
# Закономерности в данных => модель прогнозирования.

# %% [markdown]
# Адаптивный характер:
#
# - большое кол-во изменяющихся данных
# - свойства запросов и задач нестабильны
# - написать код невозможно

# %% [markdown]
# Примеры машинного обучения:
#
# - поиск в Google, результаты не сортируются по алфавиту или дате, алгоритм машинного обучения сортирует их по релевантности.
#
# - Gmail использует алгоритм машинного обучения для блокировки спама.
#
# - Google Photos использует алгоритм машинного обучения для сортировки фотографий Вас и ваших близких.

# %% [markdown]
# Машинное обучение — это наука о том, как заставить компьютеры учиться без явного программирования.

# %% [markdown]
# Машинное обучение считается подмножеством ИИ.

# %% [markdown]
# `Машинное обучение` — это тип прогнозной аналитики. (обновление в реальном времени)

# %% [markdown]
# `Глубокое обучение` — это специализированная форма машинного обучения, использующая нейронные сети (NN) для предоставления ответов.

# %% [markdown]
# ​![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Методики машинного обучения

# %% [markdown]
# В машшинной обучении рассматриваются три методики реализации алгоритмов:

# %% [markdown]
# ### Контролируемое обучение

# %% [markdown]
# При контролируемом обучении алгоритмы обеспечивают прогнозирование на основе `набора помеченных примеров`. Эта методика полезна, если вы знаете, как должен выглядеть результат.

# %% [markdown]
# При `обучении с учителем` мы должны понимать взаимосвязь между входными и выходными значениями, чтобы мы могли прогнозировать значения на основе входных данных. `Регрессия` и `классификация` - два типа задач обучения с учителем

# %% [markdown]
# - `Проблема регрессии`: если прогноз представляет собой какое-то непрерывное значение, например цену дома, то это называется проблемой регрессии.
#
# - `Проблема классификации`: если прогноз представляет собой какую-то классификацию, например, дом будет продан или нет, то это называется проблемой классификации.

# %% [markdown]
# ### Неконтролируемое обучение

# %% [markdown]
# При неконтролируемом обучении точки данных помечать не нужно. Алгоритм помечает их автоматически, упорядочивая данные или описывая их структуру. Этот метод полезен, если неизвестно, каким должен быть результат.

# %% [markdown]
# `Кластеризация` и `ассоциация` - это два типа задач обучения без учителя.

# %% [markdown]
# - `Кластеризация`: проблема кластеризации используется для поиска присущей группировки данных. Например, в случае электронной коммерции поиск группы клиентов на основе покупательского поведения.
#
# - `Ассоциация`: проблема ассоциации используется для поиска правил, описывающих большие части данных. Например, в электронной коммерции найти правило, почему клиенты, которые покупают X товаров, также склонны покупать Y товаров.

# %% [markdown]
# ### Обучение с подкреплением

# %% [markdown]
# При обучении с подкреплением используются алгоритмы, которые обучаются на результатах и определяют, какое действие следует предпринять. После каждого действия алгоритм получает отзыв, помогающий определить, является ли сделанный выбор правильным, нейтральным или неправильным.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Алгоритмы машинного обучения

# %% [markdown]
# **Алгоритмы машинного обучения** — это фрагменты кода, которые помогают пользователям исследовать и анализировать сложные наборы данных и находить в них смысл.

# %% [markdown]
# ### Алгоритмы линейной регрессии.

# %% [markdown]
# С помощью алгоритмов линейной регрессии отображается либо прогнозируется связь между двумя переменными или факторами путем вписывания в представление данных непрерывной прямой линии. Эта линия часто вычисляется с помощью функции Squared Error Cost (Стоимость среднеквадратической погрешности).

# %% [markdown]
# ​![image.png](data:image/png;base64,...)
#
#
#
# ​

# %% [markdown]
# ### Алгоритмы логистической регрессии.

# %% [markdown]
# Алгоритмы логистической регрессии позволяют вписывать в представление данных непрерывную S-образную кривую.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упрощенные алгоритмы Байеса

# %% [markdown]
# Позволяют вычислить вероятность какого-либо события в зависимости от связанного события.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Метод опорных векторов

# %% [markdown]
# Создается гиперплоскость между двумя ближайшими точками данных. Это позволяет маргинализировать классы и увеличить расстояния между ними для более четкой дифференциации.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Деревья принятия решений

# %% [markdown]
# Позволяют разбить данные на два однородных набора или более. В таких алгоритмах используются правила if-then для разделения данных на основе наиболее значимого различия между точками данных.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Случайный лес

# %% [markdown]
# Jснован на деревьях принятия решений. Но вместо одного дерева с их помощью создается лес деревьев. Затем деревья в этом лесу рандомизируются. После этого голоса от различных случайных построений деревьев принятия решений объединяются для определения конечного класса тестового объекта.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# K-ближайших соседей

# %% [markdown]
# Сохраняются все доступные точки данных и каждая новая точка данных классифицируется на основе ближайших к ней точек данных, определенных с помощью функции расстояния.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Градиентного усиления

# %% [markdown]
# Позволяют создать модель прогнозирования, в которой ненадежные модели прогнозирования (обычно деревья принятия решений) объединены с помощью процесса сборки, повышающего общую эффективность модели.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Метод K-средних

# %% [markdown]
# Позволяют классифицировать данные и группировать их в кластеры, где k равно количеству кластеров. В пределах каждого кластера точки данных являются однородными, а по отношению к точкам данных в других кластерах — разнородными.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
